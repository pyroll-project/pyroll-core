# %%
import pyroll.core as pr

# %%
pr.Profile.round(diameter=1)
# Out:
# RoundProfile(
#     classifiers={'round'},
#     cross_section=Polygon(
#         area=0.7841371226364849,
#         height=1.0,
#         perimeter=3.1403311569547543,
#         width=1.0,
#         ),
#     diameter=1,
#     radius=0.5,
#     t=0,
#     )
